# %%
# Import requests package:
import requests

# %%
# Set URL as url:
url = 'https://www.ec.europa.eu/agrifood/api/poultry/egg/prices?'

# %%
# Create parameter dictionary:
parameters = {
    'beginDate': '01/01/2021',
    'endDate': '22/01/2024'}

# %%
# Send get request and save in variable r:
r = requests.get(url, parameters)

# Print result:
print(r)
# Out:
# <Response [200]>

# %%
# Print headers:
r.headers
# Out:
# {'Date': 'Thu, 15 Feb 2024 09:41:54 GMT', 'Content-Type': 'application/json', 'Server': 'Europa', 'Connection': 'close', 'Content-Encoding': 'gzip'}

# %%
# Print cookies:
r.cookies
# Out:
# <RequestsCookieJar[]>

# %%
# Print encoding:
r.encoding
# Out:
# 'utf-8'

# %%
# Apply JSON decoder and save in prices_eggs_prelim:
prices_eggs_prelim = r.json()

# Print prices_eggs_prelim:
prices_eggs_prelim
# Out:
# [{'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€266.79',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'AT',
#   'memberStateName': 'Austria'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€334.49',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'AT',
#   'memberStateName': 'Austria'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€515.04',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'AT',
#   'memberStateName': 'Austria'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€292.47',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€255.78',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€205.03',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€327.15',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€290.33',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€251.82',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€231.03',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€260.57',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'HR',
#   'memberStateName': 'Croatia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€277.11',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'HR',
#   'memberStateName': 'Croatia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€714.90',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€364.86',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€172.91',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€264.50',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€203.44',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'CZ',
#   'memberStateName': 'Czechia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€183.16',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'CZ',
#   'memberStateName': 'Czechia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€273.20',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€512.17',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€345.35',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€260.80',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€222.64',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€374.93',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€207.35',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€447.83',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€278.63',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€243.47',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€383.04',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€244.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€537.46',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€243.36',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'EL',
#   'memberStateName': 'Greece'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€265.52',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'HU',
#   'memberStateName': 'Hungary'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€239.81',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'HU',
#   'memberStateName': 'Hungary'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€231.25',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€273.45',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€246.99',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€436.51',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€248.41',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'IT',
#   'memberStateName': 'Italy'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€282.14',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'IT',
#   'memberStateName': 'Italy'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€199.62',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€240.24',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€329.10',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€275.15',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€170.20',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'LT',
#   'memberStateName': 'Lithuania'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€431.12',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'LT',
#   'memberStateName': 'Lithuania'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€304.23',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'MT',
#   'memberStateName': 'Malta'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€271.80',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'MT',
#   'memberStateName': 'Malta'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€323.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€213.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€244.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€271.64',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€322.43',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€396.26',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€220.80',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€230.38',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€277.78',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€469.58',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€259.59',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€192.26',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€216.49',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€364.03',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€290.75',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€276.72',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'SK',
#   'memberStateName': 'Slovakia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€277.77',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'SK',
#   'memberStateName': 'Slovakia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€199.31',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'SK',
#   'memberStateName': 'Slovakia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€360.35',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€396.21',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€210.50',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€253.21',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€210.25',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€240.60',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€193.36',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€330.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€240.58',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'SE',
#   'memberStateName': 'Sweden'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€359.28',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'SE',
#   'memberStateName': 'Sweden'},
#  {'beginDate': '15/01/2024',
#   'endDate': '21/01/2024',
#   'price': '€276.73',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'SE',
#   'memberStateName': 'Sweden'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€266.59',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'AT',
#   'memberStateName': 'Austria'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€334.60',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'AT',
#   'memberStateName': 'Austria'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€511.59',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'AT',
#   'memberStateName': 'Austria'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€324.50',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€301.19',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€207.56',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€247.70',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€236.73',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€227.03',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€305.93',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€273.81',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'HR',
#   'memberStateName': 'Croatia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€270.21',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'HR',
#   'memberStateName': 'Croatia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€364.86',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€714.90',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€264.50',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€172.91',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€188.20',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'CZ',
#   'memberStateName': 'Czechia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€176.79',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'CZ',
#   'memberStateName': 'Czechia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€281.05',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€501.80',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€337.79',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€258.36',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€369.61',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€208.14',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€223.29',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€244.58',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€447.83',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€278.63',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€383.84',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€245.97',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€537.46',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€245.55',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'EL',
#   'memberStateName': 'Greece'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€241.26',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'HU',
#   'memberStateName': 'Hungary'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€269.46',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'HU',
#   'memberStateName': 'Hungary'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€246.99',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€436.88',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€274.11',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€231.72',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€248.41',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'IT',
#   'memberStateName': 'Italy'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€282.14',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'IT',
#   'memberStateName': 'Italy'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€201.31',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€329.10',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€216.39',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€301.65',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€457.78',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'LT',
#   'memberStateName': 'Lithuania'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€173.80',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'LT',
#   'memberStateName': 'Lithuania'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€271.80',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'MT',
#   'memberStateName': 'Malta'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€304.23',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'MT',
#   'memberStateName': 'Malta'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€323.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€213.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€245.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€268.71',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€325.55',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€392.15',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€228.71',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€469.58',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€259.59',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€234.79',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€277.78',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€191.65',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€290.58',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€367.73',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€214.52',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€272.01',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'SK',
#   'memberStateName': 'Slovakia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€200.27',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'SK',
#   'memberStateName': 'Slovakia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€293.47',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'SK',
#   'memberStateName': 'Slovakia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€226.65',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€241.59',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€426.03',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€406.11',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€195.83',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€212.24',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€240.54',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€330.10',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€284.03',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'SE',
#   'memberStateName': 'Sweden'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€363.41',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'SE',
#   'memberStateName': 'Sweden'},
#  {'beginDate': '08/01/2024',
#   'endDate': '14/01/2024',
#   'price': '€245.63',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'SE',
#   'memberStateName': 'Sweden'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€518.39',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'AT',
#   'memberStateName': 'Austria'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€268.42',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'AT',
#   'memberStateName': 'Austria'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€337.54',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'AT',
#   'memberStateName': 'Austria'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€263.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€357.88',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€209.89',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€301.91',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€230.32',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€238.53',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€225.43',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€265.73',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'HR',
#   'memberStateName': 'Croatia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€289.66',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'HR',
#   'memberStateName': 'Croatia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€364.86',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€264.50',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€714.90',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€172.91',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€202.10',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'CZ',
#   'memberStateName': 'Czechia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€176.79',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'CZ',
#   'memberStateName': 'Czechia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€273.29',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€334.09',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€255.14',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€454.12',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€375.60',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€209.46',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€222.94',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€447.83',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€244.58',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€278.63',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€537.46',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€381.45',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€246.34',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€247.79',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'EL',
#   'memberStateName': 'Greece'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€245.54',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'HU',
#   'memberStateName': 'Hungary'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€267.30',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'HU',
#   'memberStateName': 'Hungary'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€274.89',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€232.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€246.99',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€436.46',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€285.31',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'IT',
#   'memberStateName': 'Italy'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€251.58',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'IT',
#   'memberStateName': 'Italy'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€198.15',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€236.34',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€280.25',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€329.10',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€430.70',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'LT',
#   'memberStateName': 'Lithuania'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€174.90',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'LT',
#   'memberStateName': 'Lithuania'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€187.63',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'LT',
#   'memberStateName': 'Lithuania'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€304.23',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'MT',
#   'memberStateName': 'Malta'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€271.80',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'MT',
#   'memberStateName': 'Malta'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€324.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€214.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€246.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€230.30',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€392.53',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€275.32',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€322.31',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€234.79',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€469.58',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€277.78',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€259.59',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€340.90',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€191.40',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€252.70',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€215.35',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€205.23',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'SK',
#   'memberStateName': 'Slovakia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€295.74',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'SK',
#   'memberStateName': 'Slovakia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€240.38',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€390.69',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€235.66',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€395.59',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2024,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€329.43',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2024,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '01/01/2024',
#   'endDate': '07/01/2024',
#   'price': '€218.50',
# ...
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€250.74',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€315.33',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€297.81',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'BE',
#   'memberStateName': 'Belgium'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€185.11',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€199.48',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€279.77',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'BG',
#   'memberStateName': 'Bulgaria'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€283.29',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'HR',
#   'memberStateName': 'Croatia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€271.22',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'HR',
#   'memberStateName': 'Croatia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€264.50',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€425.40',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€714.90',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€172.91',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'CY',
#   'memberStateName': 'Cyprus'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€174.08',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'CZ',
#   'memberStateName': 'Czechia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€189.43',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'CZ',
#   'memberStateName': 'Czechia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€226.61',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€262.35',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€431.30',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€237.61',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'EE',
#   'memberStateName': 'Estonia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€377.32',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€209.98',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€223.19',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'FI',
#   'memberStateName': 'Finland'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€447.83',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€210.89',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€278.63',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'FR',
#   'memberStateName': 'France'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€381.90',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€233.68',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€500.01',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'DE',
#   'memberStateName': 'Germany'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€238.08',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'EL',
#   'memberStateName': 'Greece'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€261.58',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'HU',
#   'memberStateName': 'Hungary'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€230.74',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'HU',
#   'memberStateName': 'Hungary'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€231.51',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€436.63',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€246.99',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€272.30',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'IE',
#   'memberStateName': 'Ireland'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€252.38',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'IT',
#   'memberStateName': 'Italy'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€286.11',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'IT',
#   'memberStateName': 'Italy'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€273.98',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€230.63',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€329.10',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€207.14',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'LV',
#   'memberStateName': 'Latvia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€186.48',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'LT',
#   'memberStateName': 'Lithuania'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€510.87',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'LT',
#   'memberStateName': 'Lithuania'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€212.21',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'LT',
#   'memberStateName': 'Lithuania'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€237.53',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'MT',
#   'memberStateName': 'Malta'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€285.97',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'MT',
#   'memberStateName': 'Malta'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€203.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€235.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€313.00',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'NL',
#   'memberStateName': 'Netherlands'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€263.31',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€384.06',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€310.95',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€216.65',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'PL',
#   'memberStateName': 'Poland'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€259.59',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€469.58',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€277.78',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€234.79',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'PT',
#   'memberStateName': 'Portugal'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€295.45',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€213.83',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€184.36',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€357.44',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'RO',
#   'memberStateName': 'Romania'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€218.60',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'SK',
#   'memberStateName': 'Slovakia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€262.97',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'SK',
#   'memberStateName': 'Slovakia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€289.70',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'SK',
#   'memberStateName': 'Slovakia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€408.62',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€241.62',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€400.86',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€229.92',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'SI',
#   'memberStateName': 'Slovenia'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€196.81',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Cage',
#   'marketingYear': 2023,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€240.61',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€221.91',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'ES',
#   'memberStateName': 'Spain'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€266.37',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'SE',
#   'memberStateName': 'Sweden'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€344.53',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'SE',
#   'memberStateName': 'Sweden'},
#  {'beginDate': '23/10/2023',
#   'endDate': '29/10/2023',
#   'price': '€233.80',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Barn',
#   'marketingYear': 2023,
#   'memberStateCode': 'SE',
#   'memberStateName': 'Sweden'},
#  {'beginDate': '16/10/2023',
#   'endDate': '22/10/2023',
#   'price': '€514.77',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Organic',
#   'marketingYear': 2023,
#   'memberStateCode': 'AT',
#   'memberStateName': 'Austria'},
#  {'beginDate': '16/10/2023',
#   'endDate': '22/10/2023',
#   'price': '€340.57',
#   'unit': '€/100Kg',
#   'farmingMethod': 'Free range',
#   'marketingYear': 2023,
#   'memberStateCode': 'AT',
#   'memberStateName': 'Austria'},
#  ...]

# %%
# Print type of prices_eggs_prelim:
type(prices_eggs_prelim)
# Out:
# list

# %%
# Import pandas package:
import pandas as pd

# Transform list to dataframe:
prices_eggs = pd.DataFrame(prices_eggs_prelim)

# %%
# Show dataframe:
prices_eggs
# Out:
#         beginDate     endDate    price     unit farmingMethod  marketingYear  \
# 0      15/01/2024  21/01/2024  €266.79  €/100Kg          Barn           2024
# 1      15/01/2024  21/01/2024  €334.49  €/100Kg    Free range           2024
# 2      15/01/2024  21/01/2024  €515.04  €/100Kg       Organic           2024
# 3      15/01/2024  21/01/2024  €292.47  €/100Kg    Free range           2024
# 4      15/01/2024  21/01/2024  €255.78  €/100Kg          Barn           2024
# ...           ...         ...      ...      ...           ...            ...
# 11757  04/01/2021  10/01/2021  €241.38  €/100Kg       Organic           2021
# 11758  04/01/2021  10/01/2021   €88.64  €/100Kg          Cage           2021
# 11759  04/01/2021  10/01/2021  €310.10  €/100Kg       Organic           2021
# 11760  04/01/2021  10/01/2021  €218.24  €/100Kg    Free range           2021
# 11761  04/01/2021  10/01/2021  €179.96  €/100Kg          Barn           2021
#
#       memberStateCode memberStateName
# 0                  AT         Austria
# 1                  AT         Austria
# 2                  AT         Austria
# 3                  BE         Belgium
# 4                  BE         Belgium
# ...               ...             ...
# 11757              SI        Slovenia
# 11758              ES           Spain
# 11759              SE          Sweden
# 11760              SE          Sweden
# 11761              SE          Sweden
#
# [11762 rows x 8 columns]

# %%
# Show dataframe info:
prices_eggs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11762 entries, 0 to 11761
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   beginDate        11762 non-null  object
#  1   endDate          11762 non-null  object
#  2   price            11762 non-null  object
#  3   unit             11762 non-null  object
#  4   farmingMethod    11762 non-null  object
#  5   marketingYear    11762 non-null  int64
#  6   memberStateCode  11762 non-null  object
#  7   memberStateName  11762 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 735.2+ KB

# %%
# It appears that there are no null values.
# However, it is possible that there are null values that are not specified as such (and that are instead indicated with
# certain characters such as "." or similar).
# In order to check this, we first list the unique values of the variables that have only a limited number of values:

# %%
prices_eggs.unit.unique()
# Out:
# array(['€/100Kg'], dtype=object)

# %%
prices_eggs.farmingMethod.unique()
# Out:
# array(['Barn', 'Free range', 'Organic', 'Cage'], dtype=object)

# %%
prices_eggs.marketingYear.unique()
# Out:
# array([2024, 2023, 2022, 2021])

# %%
prices_eggs.memberStateCode.unique()
# Out:
# array(['AT', 'BE', 'BG', 'HR', 'CY', 'CZ', 'EE', 'FI', 'FR', 'DE', 'EL',
#        'HU', 'IE', 'IT', 'LV', 'LT', 'MT', 'NL', 'PL', 'PT', 'RO', 'SK',
#        'SI', 'ES', 'SE', 'DK'], dtype=object)

# %%
prices_eggs.memberStateName.unique()
# Out:
# array(['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czechia',
#        'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary',
#        'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Malta', 'Netherlands',
#        'Poland', 'Portugal', 'Romania', 'Slovakia', 'Slovenia', 'Spain',
#        'Sweden', 'Denmark'], dtype=object)

# %%
# For beginDate, endDate, and price, we sort the data by the respective variable and show the first and last
# cases in order to find out whether there are null values that are not specified as such:

# %%
prices_eggs[['beginDate']].sort_values(by='beginDate',ascending=True).head()
# Out:
#       beginDate
# 188  01/01/2024
# 210  01/01/2024
# 209  01/01/2024
# 208  01/01/2024
# 207  01/01/2024

# %%
prices_eggs[['beginDate']].sort_values(by='beginDate',ascending=True).tail()
# Out:
#        beginDate
# 4971  31/10/2022
# 4970  31/10/2022
# 4969  31/10/2022
# 4938  31/10/2022
# 4917  31/10/2022

# %%
prices_eggs[['endDate']].sort_values(by='endDate',ascending=True).head()
# Out:
#          endDate
# 4353  01/01/2023
# 4361  01/01/2023
# 4362  01/01/2023
# 4363  01/01/2023
# 4364  01/01/2023

# %%
prices_eggs[['endDate']].sort_values(by='endDate',ascending=True).tail()
# Out:
#         endDate
# 284  31/12/2023
# 285  31/12/2023
# 286  31/12/2023
# 279  31/12/2023
# 231  31/12/2023

# %%
prices_eggs[['price']].sort_values(by='price',ascending=True).head()
# Out:
#          price
# 9647   €100.23
# 10826  €100.24
# 11536  €100.25
# 9281   €100.43
# 9751   €100.53

# %%
prices_eggs[['price']].sort_values(by='price',ascending=True).tail()
# Out:
#         price
# 9893   €99.22
# 10103  €99.31
# 10672  €99.36
# 10208  €99.55
# 9935   €99.58

# %%
# We conclude that there are no null values in the dataframe.

# %%
# Show variables:
prices_eggs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11762 entries, 0 to 11761
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   beginDate        11762 non-null  object
#  1   endDate          11762 non-null  object
#  2   price            11762 non-null  object
#  3   unit             11762 non-null  object
#  4   farmingMethod    11762 non-null  object
#  5   marketingYear    11762 non-null  int64
#  6   memberStateCode  11762 non-null  object
#  7   memberStateName  11762 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 735.2+ KB

# %%
# We do not need the marketingYear variable, especially as we do not know its exact relationship with beginDate and endDate:
prices_eggs = prices_eggs.drop(['marketingYear'], axis=1)

# We do not need the unit variable, as we know that prices are measured in €/100kg:
prices_eggs = prices_eggs.drop(['unit'], axis=1)

# Rename variable names to standard format and to names we can easily work with:
prices_eggs = prices_eggs.rename(columns={'beginDate': 'begin_date'})
prices_eggs = prices_eggs.rename(columns={'endDate': 'end_date'})
prices_eggs = prices_eggs.rename(columns={'farmingMethod': 'farming_method'})
prices_eggs = prices_eggs.rename(columns={'memberStateCode': 'country_code'})
prices_eggs = prices_eggs.rename(columns={'memberStateName': 'country'})

# Show variables again:
prices_eggs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11762 entries, 0 to 11761
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   begin_date      11762 non-null  object
#  1   end_date        11762 non-null  object
#  2   price           11762 non-null  object
#  3   farming_method  11762 non-null  object
#  4   country_code    11762 non-null  object
#  5   country         11762 non-null  object
# dtypes: object(6)
# memory usage: 551.5+ KB

# %%
# Remove the € symbol in the price values:
prices_eggs['price'] = prices_eggs['price'].str.replace('€', '')

# Check results:
prices_eggs
# Out:
#        begin_date    end_date   price farming_method country_code   country
# 0      15/01/2024  21/01/2024  266.79           Barn           AT   Austria
# 1      15/01/2024  21/01/2024  334.49     Free range           AT   Austria
# 2      15/01/2024  21/01/2024  515.04        Organic           AT   Austria
# 3      15/01/2024  21/01/2024  292.47     Free range           BE   Belgium
# 4      15/01/2024  21/01/2024  255.78           Barn           BE   Belgium
# ...           ...         ...     ...            ...          ...       ...
# 11757  04/01/2021  10/01/2021  241.38        Organic           SI  Slovenia
# 11758  04/01/2021  10/01/2021   88.64           Cage           ES     Spain
# 11759  04/01/2021  10/01/2021  310.10        Organic           SE    Sweden
# 11760  04/01/2021  10/01/2021  218.24     Free range           SE    Sweden
# 11761  04/01/2021  10/01/2021  179.96           Barn           SE    Sweden
#
# [11762 rows x 6 columns]

# %%
# Transform begin_date and end_date to datetime format:
prices_eggs['begin_date'] = pd.to_datetime(prices_eggs['begin_date'], format='%d/%m/%Y')
prices_eggs['end_date'] = pd.to_datetime(prices_eggs['end_date'], format='%d/%m/%Y')

# Transform price to float:
prices_eggs['price'] = prices_eggs['price'].astype(float)

# Check results:
prices_eggs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11762 entries, 0 to 11761
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   begin_date      11762 non-null  datetime64[ns]
#  1   end_date        11762 non-null  datetime64[ns]
#  2   price           11762 non-null  float64
#  3   farming_method  11762 non-null  object
#  4   country_code    11762 non-null  object
#  5   country         11762 non-null  object
# dtypes: datetime64[ns](2), float64(1), object(3)
# memory usage: 551.5+ KB

# %%
# Transform prices from the the unit €/100kg to the unit €/kg:
prices_eggs['price'] = prices_eggs['price'] / 100

# Check results:
prices_eggs
# Out:
#       begin_date   end_date   price farming_method country_code   country
# 0     2024-01-15 2024-01-21  2.6679           Barn           AT   Austria
# 1     2024-01-15 2024-01-21  3.3449     Free range           AT   Austria
# 2     2024-01-15 2024-01-21  5.1504        Organic           AT   Austria
# 3     2024-01-15 2024-01-21  2.9247     Free range           BE   Belgium
# 4     2024-01-15 2024-01-21  2.5578           Barn           BE   Belgium
# ...          ...        ...     ...            ...          ...       ...
# 11757 2021-01-04 2021-01-10  2.4138        Organic           SI  Slovenia
# 11758 2021-01-04 2021-01-10  0.8864           Cage           ES     Spain
# 11759 2021-01-04 2021-01-10  3.1010        Organic           SE    Sweden
# 11760 2021-01-04 2021-01-10  2.1824     Free range           SE    Sweden
# 11761 2021-01-04 2021-01-10  1.7996           Barn           SE    Sweden
#
# [11762 rows x 6 columns]

# %%
# Now we calculate price premia (i.e., relative price differences) for organic vs. conventional eggs.

# %%
# Show the farming methods:
prices_eggs.farming_method.unique()
# Out:
# array(['Barn', 'Free range', 'Organic', 'Cage'], dtype=object)

# %%
# Generate dichotomous variable for product type (organic vs. conventional)

# Define function that assigns product type:
def get_product_type(farming_method):
    if farming_method == 'Organic':
        return 'Organic'
    else:
        return 'Conventional'
    
# Generate product_type variable, based on original variable on farming method:
prices_eggs['product_type'] = prices_eggs['farming_method'].apply(get_product_type)

# Check results:
prices_eggs
# Out:
#       begin_date   end_date   price farming_method country_code   country  \
# 0     2024-01-15 2024-01-21  2.6679           Barn           AT   Austria
# 1     2024-01-15 2024-01-21  3.3449     Free range           AT   Austria
# 2     2024-01-15 2024-01-21  5.1504        Organic           AT   Austria
# 3     2024-01-15 2024-01-21  2.9247     Free range           BE   Belgium
# 4     2024-01-15 2024-01-21  2.5578           Barn           BE   Belgium
# ...          ...        ...     ...            ...          ...       ...
# 11757 2021-01-04 2021-01-10  2.4138        Organic           SI  Slovenia
# 11758 2021-01-04 2021-01-10  0.8864           Cage           ES     Spain
# 11759 2021-01-04 2021-01-10  3.1010        Organic           SE    Sweden
# 11760 2021-01-04 2021-01-10  2.1824     Free range           SE    Sweden
# 11761 2021-01-04 2021-01-10  1.7996           Barn           SE    Sweden
#
#        product_type
# 0      Conventional
# 1      Conventional
# 2           Organic
# 3      Conventional
# 4      Conventional
# ...             ...
# 11757       Organic
# 11758  Conventional
# 11759       Organic
# 11760  Conventional
# 11761  Conventional
#
# [11762 rows x 7 columns]

# %%
# In order to calculate price premia, we need separate variables for
# the prices of organic and conventional eggs, so that we can relate the prices to each other.

# %%
# Create new dataframe only for organic eggs:
prices_eggs_organic = prices_eggs[prices_eggs['product_type'] == "Organic"]

# Rename price variable to specify the product type:
prices_eggs_organic = prices_eggs_organic.rename(columns={'price': 'price_organic'})

# Show dataframe:
prices_eggs_organic
# Out:
#       begin_date   end_date  price_organic farming_method country_code  \
# 2     2024-01-15 2024-01-21         5.1504        Organic           AT
# 6     2024-01-15 2024-01-21         3.2715        Organic           BE
# 12    2024-01-15 2024-01-21         7.1490        Organic           CY
# 19    2024-01-15 2024-01-21         5.1217        Organic           EE
# 23    2024-01-15 2024-01-21         3.7493        Organic           FI
# ...          ...        ...            ...            ...          ...
# 11730 2021-01-04 2021-01-10         1.3227        Organic           EL
# 11735 2021-01-04 2021-01-10         1.5708        Organic           IE
# 11748 2021-01-04 2021-01-10         3.1348        Organic           PL
# 11757 2021-01-04 2021-01-10         2.4138        Organic           SI
# 11759 2021-01-04 2021-01-10         3.1010        Organic           SE
#
#         country product_type
# 2       Austria      Organic
# 6       Belgium      Organic
# 12       Cyprus      Organic
# 19      Estonia      Organic
# 23      Finland      Organic
# ...         ...          ...
# 11730    Greece      Organic
# 11735   Ireland      Organic
# 11748    Poland      Organic
# 11757  Slovenia      Organic
# 11759    Sweden      Organic
#
# [2307 rows x 7 columns]

# %%
# Create new dataframe only for conventional eggs,
# based on the average price of conventional eggs in each week and country:
prices_eggs_convent = prices_eggs[prices_eggs['product_type'] == "Conventional"].groupby(['begin_date', 'end_date', 'country_code'])['price'].mean().reset_index()

# Rename price variable to specify the product type:
prices_eggs_convent = prices_eggs_convent.rename(columns={'price': 'price_convent'})

# Show dataframe:
prices_eggs_convent
# Out:
#      begin_date   end_date country_code  price_convent
# 0    2021-01-04 2021-01-10           AT       2.048950
# 1    2021-01-04 2021-01-10           BE       1.193500
# 2    2021-01-04 2021-01-10           BG       1.365667
# 3    2021-01-04 2021-01-10           CY       1.601800
# 4    2021-01-04 2021-01-10           CZ       1.096300
# ...         ...        ...          ...            ...
# 4027 2024-01-15 2024-01-21           PT       2.559167
# 4028 2024-01-15 2024-01-21           RO       2.331667
# 4029 2024-01-15 2024-01-21           SE       2.586550
# 4030 2024-01-15 2024-01-21           SI       2.746867
# 4031 2024-01-15 2024-01-21           SK       2.512667
#
# [4032 rows x 4 columns]

# %%
# Now we step-wise merge the prices for organic and conventional eggs (for each date and country_code) to the prices_eggs dataframe:
prices_eggs = pd.merge(prices_eggs, prices_eggs_organic[['begin_date','end_date','country_code','price_organic']], on=['begin_date','end_date','country_code'], how='left')
prices_eggs = pd.merge(prices_eggs, prices_eggs_convent[['begin_date','end_date','country_code','price_convent']], on=['begin_date','end_date','country_code'], how='left')

# Show dataframe:
prices_eggs.head(20)
# Out:
#    begin_date   end_date   price farming_method country_code   country  \
# 0  2024-01-15 2024-01-21  2.6679           Barn           AT   Austria
# 1  2024-01-15 2024-01-21  3.3449     Free range           AT   Austria
# 2  2024-01-15 2024-01-21  5.1504        Organic           AT   Austria
# 3  2024-01-15 2024-01-21  2.9247     Free range           BE   Belgium
# 4  2024-01-15 2024-01-21  2.5578           Barn           BE   Belgium
# 5  2024-01-15 2024-01-21  2.0503           Cage           BE   Belgium
# 6  2024-01-15 2024-01-21  3.2715        Organic           BE   Belgium
# 7  2024-01-15 2024-01-21  2.9033     Free range           BG  Bulgaria
# 8  2024-01-15 2024-01-21  2.5182           Barn           BG  Bulgaria
# 9  2024-01-15 2024-01-21  2.3103           Cage           BG  Bulgaria
# 10 2024-01-15 2024-01-21  2.6057           Cage           HR   Croatia
# 11 2024-01-15 2024-01-21  2.7711           Barn           HR   Croatia
# 12 2024-01-15 2024-01-21  7.1490        Organic           CY    Cyprus
# 13 2024-01-15 2024-01-21  3.6486     Free range           CY    Cyprus
# 14 2024-01-15 2024-01-21  1.7291           Cage           CY    Cyprus
# 15 2024-01-15 2024-01-21  2.6450           Barn           CY    Cyprus
# 16 2024-01-15 2024-01-21  2.0344           Barn           CZ   Czechia
# 17 2024-01-15 2024-01-21  1.8316           Cage           CZ   Czechia
# 18 2024-01-15 2024-01-21  2.7320           Barn           EE   Estonia
# 19 2024-01-15 2024-01-21  5.1217        Organic           EE   Estonia
#
#     product_type  price_organic  price_convent
# 0   Conventional         5.1504       3.006400
# 1   Conventional         5.1504       3.006400
# 2        Organic         5.1504       3.006400
# 3   Conventional         3.2715       2.510933
# 4   Conventional         3.2715       2.510933
# 5   Conventional         3.2715       2.510933
# 6        Organic         3.2715       2.510933
# 7   Conventional            NaN       2.577267
# 8   Conventional            NaN       2.577267
# 9   Conventional            NaN       2.577267
# 10  Conventional            NaN       2.688400
# 11  Conventional            NaN       2.688400
# 12       Organic         7.1490       2.674233
# 13  Conventional         7.1490       2.674233
# 14  Conventional         7.1490       2.674233
# 15  Conventional         7.1490       2.674233
# 16  Conventional            NaN       1.933000
# 17  Conventional            NaN       1.933000
# 18  Conventional         5.1217       2.931167
# 19       Organic         5.1217       2.931167

# %%
# Price premium for organic vs. conventional eggs in percent:
prices_eggs['price_organic_p'] = ( ( prices_eggs['price_organic'] - prices_eggs['price_convent'] ) / prices_eggs['price_convent'] ) * 100

# Show results:
prices_eggs.head(20)
# Out:
#    begin_date   end_date   price farming_method country_code   country  \
# 0  2024-01-15 2024-01-21  2.6679           Barn           AT   Austria
# 1  2024-01-15 2024-01-21  3.3449     Free range           AT   Austria
# 2  2024-01-15 2024-01-21  5.1504        Organic           AT   Austria
# 3  2024-01-15 2024-01-21  2.9247     Free range           BE   Belgium
# 4  2024-01-15 2024-01-21  2.5578           Barn           BE   Belgium
# 5  2024-01-15 2024-01-21  2.0503           Cage           BE   Belgium
# 6  2024-01-15 2024-01-21  3.2715        Organic           BE   Belgium
# 7  2024-01-15 2024-01-21  2.9033     Free range           BG  Bulgaria
# 8  2024-01-15 2024-01-21  2.5182           Barn           BG  Bulgaria
# 9  2024-01-15 2024-01-21  2.3103           Cage           BG  Bulgaria
# 10 2024-01-15 2024-01-21  2.6057           Cage           HR   Croatia
# 11 2024-01-15 2024-01-21  2.7711           Barn           HR   Croatia
# 12 2024-01-15 2024-01-21  7.1490        Organic           CY    Cyprus
# 13 2024-01-15 2024-01-21  3.6486     Free range           CY    Cyprus
# 14 2024-01-15 2024-01-21  1.7291           Cage           CY    Cyprus
# 15 2024-01-15 2024-01-21  2.6450           Barn           CY    Cyprus
# 16 2024-01-15 2024-01-21  2.0344           Barn           CZ   Czechia
# 17 2024-01-15 2024-01-21  1.8316           Cage           CZ   Czechia
# 18 2024-01-15 2024-01-21  2.7320           Barn           EE   Estonia
# 19 2024-01-15 2024-01-21  5.1217        Organic           EE   Estonia
#
#     product_type  price_organic  price_convent  price_organic_p
# 0   Conventional         5.1504       3.006400        71.314529
# 1   Conventional         5.1504       3.006400        71.314529
# 2        Organic         5.1504       3.006400        71.314529
# 3   Conventional         3.2715       2.510933        30.290198
# 4   Conventional         3.2715       2.510933        30.290198
# 5   Conventional         3.2715       2.510933        30.290198
# 6        Organic         3.2715       2.510933        30.290198
# 7   Conventional            NaN       2.577267              NaN
# 8   Conventional            NaN       2.577267              NaN
# 9   Conventional            NaN       2.577267              NaN
# 10  Conventional            NaN       2.688400              NaN
# 11  Conventional            NaN       2.688400              NaN
# 12       Organic         7.1490       2.674233       167.328954
# 13  Conventional         7.1490       2.674233       167.328954
# 14  Conventional         7.1490       2.674233       167.328954
# 15  Conventional         7.1490       2.674233       167.328954
# 16  Conventional            NaN       1.933000              NaN
# 17  Conventional            NaN       1.933000              NaN
# 18  Conventional         5.1217       2.931167        74.732473
# 19       Organic         5.1217       2.931167        74.732473

# %%
# The variables "price_organic" and "price_convent" are not needed anymore:
prices_eggs = prices_eggs.drop(['price_organic','price_convent'], axis=1)

# %%
# Now we upload the dataframe to the database on the server.

# %%
# Import sql_functions.py because we need some functions from that module:
import sql_functions as sqlf

# We need to restart the kernel and rerun at this point if we changed the module since we first imported it.

# %%
# Create a variable called engine using the get_engine function:
engine = sqlf.get_engine()

# %%
# We set the schema to our project name:
schema = 'capstone_organicfood'

# We set table_name to the name of the dataframe:
table_name = 'prices_eggs'

# %%
# We need psycopg2 for raising possible error message:
import psycopg2

# %%
# Write records stored in dataframe to SQL database:
if engine!=None:
    try:
        prices_eggs.to_sql(name=table_name, # name of SQL table variable
                        con=engine, # engine or connection
                        schema=schema, # our class schema variable
                        if_exists='replace', # Drop the table before inserting new values
                        index=False, # Write DataFrame index as a column
                        chunksize=5000, # Specify the number of rows in each batch to be written at a time
                        method='multi') # Pass multiple values in a single INSERT clause
        print(f"The {table_name} table was imported successfully.")
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
else:
    print('No engine')
# Out:
# The prices_eggs table was imported successfully.

# %%
# Test: query the newly created table to count the rows (we know from above that the dataframe has 11,968 cases):
sqlf.get_dataframe(f'SELECT COUNT(*) FROM {schema}.prices_eggs;')
# Out:
#    count
# 0  11968

# %%
# Worked!
